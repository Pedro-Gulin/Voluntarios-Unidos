# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine 

con_string = "mysql+pymysql://root:1234@localhost:3307/voluntarios_cajuru"
engine = create_engine(con_string)

query = """ 
    SELECT *
    FROM habilidades
"""

df_read_sql = pd.read_sql(query,engine)

# %%
df_read_sql
# Out:
#    id      nome           descricao
# 0   1  Cozinhar  Sabe conzinhar bem
